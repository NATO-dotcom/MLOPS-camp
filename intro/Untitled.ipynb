# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
# !pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 MB 40.5 MB/s eta 0:00:000m eta 0:00:01
# ...

# %%
# df = pd.read_parquet("./../data/yellow_tripdata_2023-01.parquet")

# %%
import

# %%
sklearn.__version__
# Out:
# '1.9.0'
